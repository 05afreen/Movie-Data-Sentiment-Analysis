# %%
# Import necessary libraries
import pandas as pd
from textblob import TextBlob  # For sentiment analysis

# %%
# Load the dataset
file_path = 'done_data.xls'
df = pd.read_csv(file_path)
df
# Out:
#       Unnamed: 0                                     Movie Name  Year  \
# 0              0                                The Dark Knight  2008
# 1              1                                      Inception  2010
# 2              2                                   Interstellar  2014
# 3              3  The Lord of the Rings: The Return of the King  2003
# 4              4                          The Dark Knight Rises  2012
# ...          ...                                            ...   ...
# 4220        4871                                     Deadstream  2022
# 4221        4872                                    Smiley Face  2007
# 4222        4873                                       Not Okay  2022
# 4223        4877                                Tom at the Farm  2013
# 4224        4878                                 Knox Goes Away  2023
#
#                                             Description  \
# 0     When a menace known as the Joker wreaks havoc ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4225 entries, 0 to 4224
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         4225 non-null   int64
#  1   Movie Name         4225 non-null   object
#  2   Year               4225 non-null   int64
#  3   Description        4225 non-null   object
#  4   Language           4225 non-null   object
#  5   Genres             4225 non-null   object
#  6   Rating             4225 non-null   float64
#  7   Content_rating     4225 non-null   object
#  8   MetaScore          4225 non-null   int64
#  9   Popularity         4225 non-null   int64
#  10  Director           4225 non-null   object
#  11  Writer             4225 non-null   object
#  12  Budget             4225 non-null   float64
#  13  Oscar              4225 non-null   int64
#  14  Country of Origin  4225 non-null   object
#  15  Reviews            4225 non-null   object
# ...

# %%
# Identify the text column for sentiment analysis
text_column = 'Reviews'  # Replace with the actual column name in your dataset

# Ensure no null values in the text column
df = df[df[text_column].notnull()]

# Function to calculate sentiment polarity
def analyze_sentiment(text):
    try:
        blob = TextBlob(text)
        return blob.sentiment.polarity
    except Exception as e:
        print(f"Error processing text: {text}. Error: {e}")
        return None

# Apply the sentiment analysis function
df['Sentiment'] = df[text_column].apply(analyze_sentiment)

# Optional: Categorize sentiment as Positive, Negative, or Neutral
def categorize_sentiment(polarity):
    if polarity > 0:
        return 'Positive'
    elif polarity < 0:
        return 'Negative'
    else:
        return 'Neutral'

df['Sentiment_Category'] = df['Sentiment'].apply(categorize_sentiment)

# %%
df
# Out:
#       Unnamed: 0                                     Movie Name  Year  \
# 0              0                                The Dark Knight  2008
# 1              1                                      Inception  2010
# 2              2                                   Interstellar  2014
# 3              3  The Lord of the Rings: The Return of the King  2003
# 4              4                          The Dark Knight Rises  2012
# ...          ...                                            ...   ...
# 4220        4871                                     Deadstream  2022
# 4221        4872                                    Smiley Face  2007
# 4222        4873                                       Not Okay  2022
# 4223        4877                                Tom at the Farm  2013
# 4224        4878                                 Knox Goes Away  2023
#
#                                             Description  \
# 0     When a menace known as the Joker wreaks havoc ...
# ...

# %%
Complete_move_data = 'Complete_IMDB_Data.csv'
df.to_csv(Complete_move_data, index=False)
